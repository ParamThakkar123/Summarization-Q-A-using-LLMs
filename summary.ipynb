# %%
# !pip install llmsherpa
# Out:
# Collecting llmsherpa
#   Downloading llmsherpa-0.1.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from llmsherpa) (1.26.18)
# Downloading llmsherpa-0.1.4-py3-none-any.whl (13 kB)
# Installing collected packages: llmsherpa
# Successfully installed llmsherpa-0.1.4

# %%
# !pip install llama_index
# Out:
# Collecting llama_index
#   Downloading llama_index-0.10.27-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4 (from llama_index)
#   Downloading llama_index_agent_openai-0.2.2-py3-none-any.whl.metadata (677 bytes)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_cli-0.1.11-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.11.0,>=0.10.27 (from llama_index)
#   Downloading llama_index_core-0.10.27-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama_index)
#   Downloading llama_index_embeddings_openai-0.1.7-py3-none-any.whl.metadata (603 bytes)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.5-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama_index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.13 (from llama_index)
#   Downloading llama_index_llms_openai-0.1.14-py3-none-any.whl.metadata (559 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama_index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama_index)
#   Downloading llama_index_program_openai-0.1.5-py3-none-any.whl.metadata (715 bytes)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama_index)
#   Downloading llama_index_readers_file-0.1.15-py3-none-any.whl.metadata (934 bytes)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.3.0,>=0.1.4->llama_index)
#   Downloading openai-1.16.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (3.9.1)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2024.3.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (0.27.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.16 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading llamaindex_py_client-0.1.16-py3-none-any.whl.metadata (711 bytes)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.5.8)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (3.2.1)
# Collecting nltk<4.0.0,>=3.8.1 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (9.5.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (8.2.3)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (4.66.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.14.1)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading PyMuPDF-1.24.1-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.1.0)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse<0.5.0,>=0.4.0 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama_index)
#   Downloading llama_parse-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in /opt/conda/lib/python3.10/site-packages (from llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.5.3)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (4.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.0.4)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.6)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.27->llama_index) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.27->llama_index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.3.0,>=0.1.4->llama_index) (1.9.0)
# Collecting PyMuPDFb==1.24.1 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading PyMuPDFb-1.24.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (2023.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.27->llama_index) (21.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.27->llama_index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.14.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.1.1)
# Downloading llama_index-0.10.27-py3-none-any.whl (6.9 kB)
# Downloading llama_index_agent_openai-0.2.2-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.11-py3-none-any.whl (26 kB)
# Downloading llama_index_core-0.10.27-py3-none-any.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 74.5 MB/s eta 0:00:00:00:0100:01
# Downloading llama_index_embeddings_openai-0.1.7-py3-none-any.whl (6.0 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.5-py3-none-any.whl (6.7 kB)
# Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.3 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.1.14-py3-none-any.whl (10 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Downloading llama_index_program_openai-0.1.5-py3-none-any.whl (4.1 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.15-py3-none-any.whl (36 kB)
# Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl (2.5 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 10.3 MB/s eta 0:00:00
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_parse-0.4.0-py3-none-any.whl (7.0 kB)
# Downloading llamaindex_py_client-0.1.16-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 9.6 MB/s eta 0:00:00
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 56.1 MB/s eta 0:00:00
# Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 15.4 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.1-cp310-none-manylinux2014_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 84.6 MB/s eta 0:00:00:00:01
# Downloading PyMuPDFb-1.24.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 54.6 MB/s eta 0:00:00:00:0100:01
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 65.4 MB/s eta 0:00:00
# Installing collected packages: striprtf, dirtyjson, PyMuPDFb, nltk, beautifulsoup4, tiktoken, pymupdf, openai, llamaindex-py-client, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama_index
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.2
#     Uninstalling beautifulsoup4-4.12.2:
#       Successfully uninstalled beautifulsoup4-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.8.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# Successfully installed PyMuPDFb-1.24.1 beautifulsoup4-4.12.3 dirtyjson-1.0.8 llama-index-agent-openai-0.2.2 llama-index-cli-0.1.11 llama-index-core-0.10.27 llama-index-embeddings-openai-0.1.7 llama-index-indices-managed-llama-cloud-0.1.5 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.14 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.5 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.15 llama-index-readers-llama-parse-0.1.4 llama-parse-0.4.0 llama_index-0.10.27 llamaindex-py-client-0.1.16 nltk-3.8.1 openai-1.16.2 pymupdf-1.24.1 striprtf-0.0.26 tiktoken-0.6.0

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.1.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.33)
# Collecting langchain-community<0.1,>=0.0.30 (from langchain)
#   Downloading langchain_community-0.0.31-py3-none-any.whl.metadata (8.4 kB)
# Collecting langchain-core<0.2.0,>=0.1.37 (from langchain)
#   Downloading langchain_core-0.1.40-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.40-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.5.3)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.37->langchain)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Downloading langchain-0.1.14-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 21.1 MB/s eta 0:00:0000:01
# Downloading langchain_community-0.0.31-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.3 MB/s eta 0:00:00:00:01
# Downloading langchain_core-0.1.40-py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 16.9 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Downloading langsmith-0.1.40-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.8 MB/s eta 0:00:00
# Downloading orjson-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 8.8 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: packaging, orjson, langsmith, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.10
#     Uninstalling orjson-3.9.10:
#       Successfully uninstalled orjson-3.9.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.8.2 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# jupyterlab 4.1.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.3.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed langchain-0.1.14 langchain-community-0.0.31 langchain-core-0.1.40 langchain-text-splitters-0.0.1 langsmith-0.1.40 orjson-3.10.0 packaging-23.2

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /opt/conda/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.10/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)

# %%
# !pip install llama-cpp-python
# Out:
# Collecting llama-cpp-python
#   Downloading llama_cpp_python-0.2.60.tar.gz (37.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 44.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from llama-cpp-python) (4.9.0)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.10/site-packages (from llama-cpp-python) (1.26.4)
# Collecting diskcache>=5.6.1 (from llama-cpp-python)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in /opt/conda/lib/python3.10/site-packages (from llama-cpp-python) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.11.3->llama-cpp-python) (2.1.3)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.3 MB/s eta 0:00:00
# Building wheels for collected packages: llama-cpp-python
#   Building wheel for llama-cpp-python (pyproject.toml) ... done
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.2.60-cp310-cp310-manylinux_2_31_x86_64.whl size=2948780 sha256=ebb03e66817c70536b3e00305a17a16e51d18805428e9bc0a2a5153895b3ae90
#   Stored in directory: /root/.cache/pip/wheels/ad/7b/02/5200ea3612eca540182654a0b72f0b2a90c0f32d1633c931e4
# Successfully built llama-cpp-python
# Installing collected packages: diskcache, llama-cpp-python
# Successfully installed diskcache-5.6.3 llama-cpp-python-0.2.60

# %%
# !pip install ctransformers
# Out:
# Collecting ctransformers
#   Downloading ctransformers-0.2.27-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from ctransformers) (0.21.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (2024.3.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (2024.2.2)
# Downloading ctransformers-0.2.27-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 66.9 MB/s eta 0:00:00:00:010:01
# Installing collected packages: ctransformers
# Successfully installed ctransformers-0.2.27

# %%
# !pip install fpdf
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40703 sha256=aabdd51f630196c827645ec2b27f1c7dbf63c9a2a61dc27545ae9499df88ebcc
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
import langchain 
from torch import cuda, bfloat16
import torch
import transformers
from transformers import AutoTokenizer
from time import time
from langchain.llms import HuggingFacePipeline
from langchain.document_loaders import TextLoader,PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import MapReduceDocumentsChain, ReduceDocumentsChain,ConversationalRetrievalChain,StuffDocumentsChain
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain.llms import CTransformers
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.memory import ConversationBufferMemory
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain import PromptTemplate, LLMChain

# %%
# !wget "https://huggingface.co/TheBloke/zephyr-7B-beta-GGUF/resolve/main/zephyr-7b-beta.Q4_K_M.gguf"
# Out:
# --2024-04-09 04:38:13--  https://huggingface.co/TheBloke/zephyr-7B-beta-GGUF/resolve/main/zephyr-7b-beta.Q4_K_M.gguf
# Resolving huggingface.co (huggingface.co)... 3.163.189.74, 3.163.189.90, 3.163.189.37, ...
# Connecting to huggingface.co (huggingface.co)|3.163.189.74|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.huggingface.co/repos/fe/17/fe17596731f84a0d03bece77489780bc7e068323c0aeca88b6393d3e9e65dd49/503580dce392c6e64669ad21a77023ba2a17baa0c381250fb67c11ba6406a85e?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27zephyr-7b-beta.Q4_K_M.gguf%3B+filename%3D%22zephyr-7b-beta.Q4_K_M.gguf%22%3B&Expires=1712896693&Policy=&Signature=bEgd-J03DgSlcq1TUAEY6zS74Of%7EZNtQFfdoLSLngwQHeH2tqTLRqNvebSmwLqytj1t2nojV02avQ6uIUczdz77e9fhxVwMilUX1lQvkdlxol0mrwTVU8ZdxnT8l813vTViflJC2os8CkYU9gN3bGL-oyVQpbOmlkYwlvuo8Oo7TRDb6963LAunBYXXJp6JNi242Ens7xhAhfshOiexuZ9OHWcZIju4mSlF%7Ea0VzSsw%7EzvPm3DnoF-j-iVR69ST4sbI7hfx4hLLLVaRGVlnKQf0GhxOUpLU28OwM3LknW2yQaodkqoZvXGL7LdIrTXiLkyxIFE3bEcqCJ3Q0qEsFJw__&Key-Pair-Id=KCD77M1F0VK2B [following]
# --2024-04-09 04:38:13--  https://cdn-lfs-us-1.huggingface.co/repos/fe/17/fe17596731f84a0d03bece77489780bc7e068323c0aeca88b6393d3e9e65dd49/503580dce392c6e64669ad21a77023ba2a17baa0c381250fb67c11ba6406a85e?response-content-disposition=attachment%3B+filename*%3DUTF-8''zephyr-7b-beta.Q4_K_M.gguf%3B+filename%3D%22zephyr-7b-beta.Q4_K_M.gguf%22%3B&Expires=1712896693&Policy=&Signature=bEgd-J03DgSlcq1TUAEY6zS74Of~ZNtQFfdoLSLngwQHeH2tqTLRqNvebSmwLqytj1t2nojV02avQ6uIUczdz77e9fhxVwMilUX1lQvkdlxol0mrwTVU8ZdxnT8l813vTViflJC2os8CkYU9gN3bGL-oyVQpbOmlkYwlvuo8Oo7TRDb6963LAunBYXXJp6JNi242Ens7xhAhfshOiexuZ9OHWcZIju4mSlF~a0VzSsw~zvPm3DnoF-j-iVR69ST4sbI7hfx4hLLLVaRGVlnKQf0GhxOUpLU28OwM3LknW2yQaodkqoZvXGL7LdIrTXiLkyxIFE3bEcqCJ3Q0qEsFJw__&Key-Pair-Id=KCD77M1F0VK2B
# Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 3.163.189.20, 3.163.189.91, 3.163.189.28, ...
# Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|3.163.189.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4368438976 (4.1G) [binary/octet-stream]
# Saving to: 'zephyr-7b-beta.Q4_K_M.gguf'
#
# zephyr-7b-beta.Q4_K 100%[===================>]   4.07G  49.8MB/s    in 82s
#
# 2024-04-09 04:39:35 (51.0 MB/s) - 'zephyr-7b-beta.Q4_K_M.gguf' saved [4368438976/4368438976]

# %%
from llmsherpa.readers import LayoutPDFReader
from langchain_community.document_loaders.llmsherpa import LLMSherpaFileLoader

# %%
llm = CTransformers(model="/kaggle/working/zephyr-7b-beta.Q4_K_M.gguf", model_type="llama", streaming=True, 
                    callbacks=[StreamingStdOutCallbackHandler()],
                    config={'max_new_tokens':4096,'temperature':0.01, 'context_length':4096})

# %%
def summary_generation(file_path):
    loader = LLMSherpaFileLoader(
        file_path=file_path,
        new_indent_parser=True,
        apply_ocr=True,
        strategy="text",
        llmsherpa_api_url="https://readers.llmsherpa.com/api/document/developer/parseDocument?renderFormat=all",
    )
    docs = loader.load()
    map_template = """The following is a set of documents
    {docs}
    write a 100 words summary of the document covering all points. Provide the response in bullet points
    Helpful Answer:"""
    map_prompt = PromptTemplate.from_template(map_template)
    map_chain = LLMChain(llm=llm, prompt=map_prompt)
    reduce_template = """The following is set of summaries:
    {docs}
    Take these and distill it into a final, consolidated summary of the main topics and concepts that should include definitions and formulas of the concepts.Mention all the key points and formulas related to a concept. 
    Expand the description of each topic and concept for 2-3 lines.
    Helpful Answer:"""
    reduce_prompt = PromptTemplate.from_template(reduce_template)
    reduce_chain = LLMChain(llm=llm, prompt=reduce_prompt)
    combine_documents_chain = StuffDocumentsChain(
        llm_chain=reduce_chain, document_variable_name="docs"
    )
    
    reduce_documents_chain = ReduceDocumentsChain(
        combine_documents_chain=combine_documents_chain,
        collapse_documents_chain=combine_documents_chain,
        token_max=4000,
    )
    
    map_reduce_chain = MapReduceDocumentsChain(
        llm_chain=map_chain,
        reduce_documents_chain=reduce_documents_chain,
        document_variable_name="docs",
        return_intermediate_steps=False,
    )

    text_splitter = CharacterTextSplitter.from_tiktoken_encoder(
        chunk_size=1000, chunk_overlap=50
    )
    split_docs = text_splitter.split_documents(docs)
    all_summaries=map_reduce_chain.run(split_docs)
    print(all_summaries)
    
    return all_summaries

# %%
summary = summary_generation("/kaggle/input/pdffiles/pdf/nvidia.pdf")
# Out:
# - NVIDIA Corporation (NVIDIA) has filed its Form 10-Q for the quarter ended October 29, 2023.
# - The company's financial statements for the three and nine months ended October 29, 2023 and October 30, 2022 are included in the filing. These statements include condensed consolidated statements of income, comprehensive income, balance sheets, shareholders' equity, and cash flows.
# - NVIDIA's management discusses its financial condition and results of operations in Item 2 of the filing. This section covers topics such as revenue trends, gross margin, operating expenses, net income, and cash flow from operations.
# - The company also provides quantitative and qualitative disclosures about market risk in Item 3. This section discusses factors that could affect NVIDIA's financial results, such as foreign currency fluctuations and interest rate changes.
# - In Item 4, NVIDIA describes its internal controls and procedures. This section outlines the company's policies and processes for financial reporting, compliance with laws and regulations, and risk management.
# - Legal proceedings against NVIDIA are discussed in Item 1. This section covers ongoing litigation related to intellectual property, antitrust claims, and product liability lawsuits.
# - Risk factors that could affect NVIDIA's business and financial results are detailed in Item 1A. These risks include competition, regulatory developments, economic conditions, and technological advancements.
# - Unregistered sales of equity securities, use of proceeds, and issuer purchases of equity securities are covered in Item 2. This section explains the circumstances under which NVIDIA has sold unregistered securities and how it uses the proceeds from these sales.
# - Other information is provided in Item 5. This section includes updates on recent developments at NVIDIA, such as new product launches and strategic partnerships.
# - The filing concludes with a list of exhibits attached to the document. These exhibits include financial statements, contracts, and other supporting materials.
# - The signature page is included in Item 6. This section lists the names and titles of NVIDIA's officers and directors who have signed the filing.
#
# - NVIDIA Corporation and its subsidiaries have provided unaudited financial statements for the three and nine months ended October 29, 2023 and October 30, 2022.
# - Revenue for the third quarter of fiscal year 2024 was $18.1 billion, compared to $5.9 billion in the same period last year. For the first nine months of fiscal year 2024, revenue was $38.8 billion, up from $20.9 billion in the same period last year.
# - Gross profit for the third quarter was $13.4 billion, compared to $3.2 billion in the same period last year. For the first nine months of fiscal year 2024, gross profit was $27.6 billion, up from $11.5 billion in the same period last year.
# - Operating expenses for the third quarter were $2.98 billion, compared to $2.58 billion in the same period last year. For the first nine months of fiscal year 2024, operating expenses were $8.15 billion, up from $8.56 billion in the same period last year.
# - Operating income for the third quarter was $10.4 billion, compared to $601 million in the same period last year. For the first nine months of fiscal year 2024, operating income was $19.7 billion, up from $2.89 billion in the same period last year.
# - NVIDIA reported net income of $9.2 billion for the third quarter, compared to $680 million in the same period last year. For the first nine months of fiscal year 2024, net income was $17.5 billion, up from $2.95 billion in the same period last year.
# - Basic earnings per share were $3.75 for the third quarter and $7.07 for the first nine months of fiscal year 2024. Diluted earnings per share were $3.71 for the third quarter and $7.01 for the first nine months of fiscal year 2024.
# - NVIDIA uses social media channels, including its company blog, LinkedIn page, Facebook page, Instagram page, Twitter account, and YouTube channel, to disclose information about the company, products, financial announcements, attendance at conferences, and other matters. Investors should monitor these channels as well as press releases, SEC filings, and public conference calls and webcasts for material information.
# - This document is not a part of NVIDIA's Quarterly Report on Form 10-Q. Additional financial information may be found on the company's investor relations website. The list of social media channels used by NVIDIA may be updated from time to time.
#
# - NVIDIA Corporation and its subsidiaries reported condensed consolidated statements of comprehensive income for the three and nine months ended October 29, 2023, and October 30, 2022.
# - Net income for the third quarter of 2023 was $9,243 million compared to $680 million in the same period last year. For the first nine months of 2023, net income was $17,475 million versus $2,954 million in 2022.
# - Other comprehensive loss for the third quarter of 2023 was $(37) million compared to $(33) million in the same period last year. For the first nine months of 2023, other comprehensive loss was $(45) million versus $(112) million in 2022.
# - Cash flow hedges resulted in a net change in unrealized loss of $(37) million for the third quarter of 2023 and $(15) million for the first nine months of 2023. Reclassification adjustments for net realized losses included in net income were $(14) million for both the third quarter and first nine months of 2023.
# - Available-for-sale securities resulted in a net change in unrealized gain of $7 million for the third quarter of 2023 and a net change in unrealized loss of $(52) million for the first nine months of 2023.
# - NVIDIA Corporation and its subsidiaries reported condensed consolidated balance sheets as of October 29, 2023, and January 29, 2023. Total assets were $54,148 million at the end of the third quarter of 2023 compared to $41,182 million at the end of the first quarter of 2023. Total liabilities and shareholders' equity were $54,148 million and $41,182 million, respectively, at the end of the third quarter of 2023 compared to $41,182 million and $22,101 million, respectively, at the end of the first quarter of 2023.
# - Assets included cash and cash equivalents of $5,519 million, marketable securities of $12,762 million, accounts receivable, net of $8,309 million, inventories of $4,779 million, prepaid expenses and other current assets of $1,289 million, property and equipment, net of $3,844 million, operating lease assets of $1,316 million, goodwill of $4,430 million, intangible assets, net of $1,251 million, deferred income tax assets of $5,982 million, and other assets of $4,667 million.
# - Liabilities included accounts payable of $2,380 million, accrued and other current liabilities of $5,472 million, short-term debt of $1,249 million, long-term debt of $8,457 million, long-term operating lease liabilities of $1,091 million, and other long-term liabilities of $2,234 million.
# - Shareholders' equity included preferred stock of $0, common stock of $2 million, additional paid-in capital of $12,991 million, accumulated other comprehensive loss of $(88) million, and retained earnings of $20,360 million.
#
# - NVIDIA Corporation and its subsidiaries reported condensed consolidated statements of shareholders' equity for the three months ended October 29, 2023 and October 30, 2022.
# - As of October 29, 2023, there were 2,466 million common shares outstanding with additional paid-in capital of $12,991 million and accumulated other comprehensive loss of $88 million. Retained earnings stood at $20,360 million, resulting in total shareholders' equity of $33,265 million.
# - For the three months ended October 29, 2023, net income was $9,243 million, other comprehensive loss was $(37) million, shares issued from stock plans were 157 million, tax withholding related to vesting of restricted stock units was $(764) million, shares repurchased were $(14) million, and cash dividends declared and paid were $(99) million. Stock-based compensation was $983 million.
# - As of July 30, 2023, there were 2,469 million common shares outstanding with additional paid-in capital of $12,629 million and accumulated other comprehensive loss of $(51) million. Retained earnings stood at $14,921 million, resulting in total shareholders' equity of $27,501 million.
# - For the three months ended July 30, 2023, net income was $680 million, other comprehensive loss was $(33) million, shares issued from stock plans were 143 million, tax withholding related to vesting of restricted stock units was $(294) million, shares repurchased were $(1) million, and cash dividends declared and paid were $(100) million. Stock-based compensation was $749 million.
# - As of October 30, 2022, there were 2,468 million common shares outstanding with additional paid-in capital of $11,565 million and accumulated other comprehensive loss of $(123) million. Retained earnings stood at $9,905 million, resulting in total shareholders' equity of $21,349 million.
# - For the three months ended October 30, 2022, net income was $6,803 million, other comprehensive loss was $(33) million, shares issued from stock plans were 9 million, tax withholding related to vesting of restricted stock units was $(294) million, shares repurchased were $(28) million, and cash dividends declared and paid were $(100) million. Stock-based compensation was $749 million.
#
#
# - NVIDIA Corporation and its subsidiaries reported condensed consolidated statements of shareholders' equity for the nine months ended October 29, 2023 and October 30, 2022.
# - As of January 29, 2023, there were 2,466 million common shares outstanding with additional paid-in capital of $2 million. Accumulated other comprehensive loss was $11,971 million and retained earnings were $10,171 million, resulting in total shareholders' equity of $22,101 million.
# - For the nine months ended October 29, 2023, net income was $17,475 million, other comprehensive loss was $(45) million, shares issued from stock plans were 21 million, tax withholding related to vesting of restricted stock units was $(1,942) million, shares repurchased were (16) million, and cash dividends declared and paid were $(296) million. Stock-based compensation was $2,574 million.
# - As of January 30, 2022, there were 2,506 million common shares outstanding with additional paid-in capital of $3 million. Accumulated other comprehensive loss was $(11) million and retained earnings were $16,235 million, resulting in total shareholders' equity of $26,612 million.
# - For the nine months ended October 30, 2022, net income was $2,954 million, other comprehensive loss was $(112) million, shares issued from stock plans were 24 million, tax withholding related to vesting of restricted stock units was $(1,131) million, shares repurchased were (56) million and (1) million at an average price of $78.90 per share, and cash dividends declared and paid were $(300) million. Stock-based compensation was $1,965 million.
# - As of October 29, 2023 and October 30, 2022, there were 2,468 million and 2,468 million common shares outstanding, respectively. Additional paid-in capital was $2 million for both periods. Accumulated other comprehensive loss was $(123) million as of October 29, 2023 and $(11) million as of October 30, 2022. Retained earnings were $20,360 million and $9,905 million as of October 29, 2023 and October 30, 2022, respectively. Total shareholders' equity was $33,265 million and $21,349 million as of October 29, 2023 and October 30, 2022, respectively.
#
# - NVIDIA Corporation and its subsidiaries reported condensed consolidated statements of cash flows for the nine months ended October 29, 2023, and October 30, 2022.
# - Net income for the period was $17.475 million in 2023 and $2.954 million in 2022.
# - Cash flows from operating activities:
#     - Stock-based compensation expense: $2,555 million in 2023 and $1,971 million in 2022.
#     - Depreciation and amortization: $1,121 million in 2023 and $1,118 million in 2022.
#     - Losses on investments in non-affiliates: $24 million in 2023 and $35 million in 2022.
#     - Deferred income taxes: ($2,411) million in 2023 and ($1,517) million in 2022.
#     - Acquisition termination cost: $0 in 2023 and $1,353 million in 2022.
#     - Other: ($170) million in 2023 and ($27) million in 2022.
#     - Changes in operating assets and liabilities, net of acquisitions:
#         - Accounts receivable: ($4,482) million in 2023 and ($258) million in 2022.
#         - Inventories: $405 million in 2023 and ($1,848) million in 2022.
#         - Prepaid expenses and other assets: ($337) million in 2023 and ($1,307) million in 2022.
#         - Accounts payable: $1,250 million in 2023 and ($358) million in 2022.
#         - Accrued and other current liabilities: $953 million in 2023 and $1,175 million in 2022.
#         - Other long-term liabilities: $208 million in 2023 and $102 million in 2022.
#     - Net cash provided by operating activities: $16,591 million in 2023 and $3,393 million in 2022.
# - Cash flows from investing activities:
#     - Proceeds from maturities of marketable securities: $8,001 million in 2023 and $16,792 million in 2022.
#     - Proceeds from sales of marketable securities: $0 in 2023 and $1,806 million in 2022.
#     - Purchases of marketable securities: ($10,688) million in 2023 and ($9,764) million in 2022.
#     - Purchases related to property and equipment and intangible assets: ($815) million in 2023 and ($1,324) million in 2022.
#     - Acquisitions, net of cash acquired: ($83) million in 2023 and ($49) million in 2022.
#     - Investments in non-affiliates and other, net: ($872) million in 2023 and ($83) million in 2022.
#     - Net cash provided by (used in) investing activities: ($4,457) million in 2023 and $7,378 million in 2022.
# - Cash flows from financing activities:
#     - Proceeds related to employee stock plans: $403 million in 2023 and $349 million in 2022.
#     - Payments related to repurchases of common stock: ($6,874) million in 2023 and ($8,826) million in 2022.
#     - Repayment of debt: ($1,250) million in 2023 and $0 in 2022.
#     - Payments related to tax on restricted stock units: ($1,942) million in 2023 and ($1,131) million in 2022.
#     - Dividends paid: ($296) million in 2023 and ($300) million in 2022.
#     - Principal payments on property and equipment and intangible assets: ($44) million in 2023 and ($54) million in 2022.
#     - Other: ($1) million in 2023 and $1 million in 2022.
#     - Net cash used in financing activities: ($10,004) million in 2023 and ($9,961) million in 2022.
# - Change in cash, cash equivalents, and restricted cash: $2,130 million in 2023 and $810 million in 2022.
# - Cash, cash equivalents, and restricted cash at beginning of period: $3,389 million in 2023 and $1,990 million in 2022.
# - Cash, cash equivalents, and restricted cash at end of period: $5,519 million in 2023 and $2,800 million in 2022.
# - Supplemental disclosure of cash flow information:
#     - Cash paid for income taxes, net: $4,676 million in 2023 and $1,372 million in 2022.
#
# - NVIDIA Corporation and its subsidiaries reported condensed consolidated financial statements for the three and nine months ended October 29, 2023, and October 30, 2022.
# - Revenue for the third quarter of 2023 was $18.1 billion, a significant increase from $5.9 billion in the same period last year. For the first nine months of 2023, revenue totaled $38.8 billion compared to $20.9 billion in 2022.
# - Cost of revenue for the third quarter was $4.7 billion, up from $2.8 billion in Q3 2022. For the first nine months, cost of revenue reached $11.3 billion versus $9.4 billion last year.
# - Gross profit for the third quarter was $13.4 billion, a substantial increase from $3.1 billion in Q3 2022. In the first nine months, gross profit totaled $27.5 billion compared to $11.5 billion in 2022.
# - Operating expenses for the third quarter were $2.98 billion, higher than $2.58 billion in Q3 2022. For the first nine months, operating expenses totaled $8.15 billion versus $5.39 billion last year.
# - NVIDIA reported an operating income of $10.417 billion for the third quarter and $19.712 billion in the first nine months of 2023. In contrast, operating income was $601 million in Q3 2022 and $2.893 billion in the first nine months of last year.
# - NVIDIA's net income for the third quarter was $9.243 billion, compared to $680 million in Q3 2022. For the first nine months, net income totaled $17.475 billion versus $2.954 billion last year.
# - NVIDIA's weighted average shares used in per share computation for the third quarter were 2,468 million and 2,495 million for basic and diluted earnings per share, respectively. For the first nine months, the figures were 2,470 million and 2,494 million, respectively.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430 billion versus $2.842 billion last year.
# - NVIDIA's net income for the third quarter included a $105 million other income (expense), net, compared to $12 million in Q3 2022. For the first nine months, other income (expense), net was $354 million versus ($75) million last year.
# - NVIDIA's total comprehensive income for the third quarter was $9.206 billion compared to $647 million in Q3 2022. For the first nine months, total comprehensive income was $17.430
